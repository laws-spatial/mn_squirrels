# %%
import filecmp
# reading files
f1 = open("./environment.yml", "r") 
f2 = open("./environment_geoviews.yml", "r")

# %%
f1_data = f1.readlines()
f2_data = f2.readlines()
 
i = 0
 
for line1 in f1_data:
    i += 1
     
    for line2 in f2_data:
         
        # matching line1 from both files
        if line1 == line2: 
            # print IDENTICAL if similar
            print("Line ", i, ": IDENTICAL")      
        else:
            print("Line ", i, ":")
            # else print that line from both files
            print("\tFile 1:", line1, end='')
            print("\tFile 2:", line2, end='')
        break
 
# closing files
f1.close()                                      
f2.close()
# Out:
# Line  1 : IDENTICAL
# Line  2 :
# 	File 1: channels:
# 	File 2: name: squirrel4
# Line  3 :
# 	File 1:   - pyviz
# 	File 2: name: squirrel4
# Line  4 :
# 	File 1:   - conda-forge
# 	File 2: name: squirrel4
# Line  5 :
# 	File 1:   - defaults
# 	File 2: name: squirrel4
# Line  6 :
# 	File 1: dependencies:
# 	File 2: name: squirrel4
# Line  7 :
# 	File 1:   - anyio=3.6.2=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  8 :
# 	File 1:   - appdirs=1.4.4=pyh9f0ad1d_0
# 	File 2: name: squirrel4
# Line  9 :
# 	File 1:   - argon2-cffi=21.3.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  10 :
# 	File 1:   - argon2-cffi-bindings=21.2.0=py39ha55989b_3
# 	File 2: name: squirrel4
# Line  11 :
# 	File 1:   - asttokens=2.2.1=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  12 :
# 	File 1:   - attrs=22.2.0=pyh71513ae_0
# 	File 2: name: squirrel4
# Line  13 :
# 	File 1:   - backcall=0.2.0=pyh9f0ad1d_0
# 	File 2: name: squirrel4
# Line  14 :
# 	File 1:   - backports=1.0=pyhd8ed1ab_3
# 	File 2: name: squirrel4
# Line  15 :
# 	File 1:   - backports.functools_lru_cache=1.6.4=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  16 :
# 	File 1:   - beautifulsoup4=4.11.2=pyha770c72_0
# 	File 2: name: squirrel4
# Line  17 :
# 	File 1:   - bleach=6.0.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  18 :
# 	File 1:   - blosc=1.21.3=hdccc3a2_0
# 	File 2: name: squirrel4
# Line  19 :
# 	File 1:   - bokeh=2.4.3=pyhd8ed1ab_3
# 	File 2: name: squirrel4
# Line  20 :
# 	File 1:   - boost-cpp=1.78.0=h9f4b32c_1
# 	File 2: name: squirrel4
# Line  21 :
# 	File 1:   - branca=0.6.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  22 :
# 	File 1:   - brotli=1.0.9=hcfcfb64_8
# 	File 2: name: squirrel4
# Line  23 :
# 	File 1:   - brotli-bin=1.0.9=hcfcfb64_8
# 	File 2: name: squirrel4
# Line  24 :
# 	File 1:   - brotlipy=0.7.0=py39ha55989b_1005
# 	File 2: name: squirrel4
# Line  25 :
# 	File 1:   - bzip2=1.0.8=h8ffe710_4
# 	File 2: name: squirrel4
# Line  26 :
# 	File 1:   - ca-certificates=2022.12.7=h5b45459_0
# 	File 2: name: squirrel4
# Line  27 :
# 	File 1:   - cairo=1.16.0=hd694305_1014
# 	File 2: name: squirrel4
# Line  28 :
# 	File 1:   - cartopy=0.21.1=py39h25ee47b_0
# 	File 2: name: squirrel4
# Line  29 :
# 	File 1:   - certifi=2022.12.7=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  30 :
# 	File 1:   - cffi=1.15.1=py39h68f70e3_3
# 	File 2: name: squirrel4
# Line  31 :
# 	File 1:   - cftime=1.6.2=py39hc266a54_1
# 	File 2: name: squirrel4
# Line  32 :
# 	File 1:   - cfitsio=4.2.0=h9ebe7e4_0
# 	File 2: name: squirrel4
# Line  33 :
# 	File 1:   - charset-normalizer=2.1.1=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  34 :
# 	File 1:   - click=8.1.3=win_pyhd8ed1ab_2
# 	File 2: name: squirrel4
# Line  35 :
# 	File 1:   - cloudpickle=2.2.1=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  36 :
# 	File 1:   - colorama=0.4.6=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  37 :
# 	File 1:   - colorcet=3.0.1=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  38 :
# 	File 1:   - comm=0.1.2=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  39 :
# 	File 1:   - contourpy=1.0.7=py39h1f6ef14_0
# 	File 2: name: squirrel4
# Line  40 :
# 	File 1:   - cryptography=39.0.1=py39hb6bd5e6_0
# 	File 2: name: squirrel4
# Line  41 :
# 	File 1:   - curl=7.88.1=h68f0423_0
# 	File 2: name: squirrel4
# Line  42 :
# 	File 1:   - cycler=0.11.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  43 :
# 	File 1:   - dask-core=2023.2.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  44 :
# 	File 1:   - datashader=0.14.4=py_0
# 	File 2: name: squirrel4
# Line  45 :
# 	File 1:   - datashape=0.5.4=py_1
# 	File 2: name: squirrel4
# Line  46 :
# 	File 1:   - dask-geopandas=0.3.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  47 :
# 	File 1:   - debugpy=1.6.6=py39h99910a6_0
# 	File 2: name: squirrel4
# Line  48 :
# 	File 1:   - decorator=5.1.1=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  49 :
# 	File 1:   - defusedxml=0.7.1=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  50 :
# 	File 1:   - entrypoints=0.4=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  51 :
# 	File 1:   - executing=1.2.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  52 :
# 	File 1:   - expat=2.5.0=h1537add_0
# 	File 2: name: squirrel4
# Line  53 :
# 	File 1:   - flit-core=3.8.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  54 :
# 	File 1:   - folium=0.14.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  55 :
# 	File 1:   - font-ttf-dejavu-sans-mono=2.37=hab24e00_0
# 	File 2: name: squirrel4
# Line  56 :
# 	File 1:   - font-ttf-inconsolata=3.000=h77eed37_0
# 	File 2: name: squirrel4
# Line  57 :
# 	File 1:   - font-ttf-source-code-pro=2.038=h77eed37_0
# 	File 2: name: squirrel4
# Line  58 :
# 	File 1:   - font-ttf-ubuntu=0.83=hab24e00_0
# 	File 2: name: squirrel4
# Line  59 :
# 	File 1:   - fontconfig=2.14.2=hbde0cde_0
# 	File 2: name: squirrel4
# Line  60 :
# 	File 1:   - fonts-conda-ecosystem=1=0
# 	File 2: name: squirrel4
# Line  61 :
# 	File 1:   - fonts-conda-forge=1=0
# 	File 2: name: squirrel4
# Line  62 :
# 	File 1:   - fonttools=4.38.0=py39ha55989b_1
# 	File 2: name: squirrel4
# Line  63 :
# 	File 1:   - freetype=2.12.1=h546665d_1
# 	File 2: name: squirrel4
# Line  64 :
# 	File 1:   - freexl=1.0.6=h67ca5e6_1
# 	File 2: name: squirrel4
# Line  65 :
# 	File 1:   - fribidi=1.0.10=h8d14728_0
# 	File 2: name: squirrel4
# Line  66 :
# 	File 1:   - fsspec=2023.1.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  67 :
# 	File 1:   - gdal=3.6.2=py39h3be0312_7
# 	File 2: name: squirrel4
# Line  68 :
# 	File 1:   - geopandas-base=0.12.2=pyha770c72_0
# 	File 2: name: squirrel4
# Line  69 :
# 	File 1:   - geos=3.11.1=h1537add_0
# 	File 2: name: squirrel4
# Line  70 :
# 	File 1:   - geotiff=1.7.1=hc256dc0_6
# 	File 2: name: squirrel4
# Line  71 :
# 	File 1:   - geoviews=1.9.6
# 	File 2: name: squirrel4
# Line  72 :
# 	File 1:   - getopt-win32=0.1=h8ffe710_0
# 	File 2: name: squirrel4
# Line  73 :
# 	File 1:   - gettext=0.21.1=h5728263_0
# 	File 2: name: squirrel4
# Line  74 :
# 	File 1:   - glib=2.74.1=h12be248_1
# 	File 2: name: squirrel4
# Line  75 :
# 	File 1:   - glib-tools=2.74.1=h12be248_1
# 	File 2: name: squirrel4
# Line  76 :
# 	File 1:   - graphite2=1.3.13=1000
# 	File 2: name: squirrel4
# Line  77 :
# 	File 1:   - graphviz=7.1.0=h51cb2cd_0
# 	File 2: name: squirrel4
# Line  78 :
# 	File 1:   - gst-plugins-base=1.22.0=h001b923_0
# 	File 2: name: squirrel4
# Line  79 :
# 	File 1:   - gstreamer=1.22.0=h6b5321d_0
# 	File 2: name: squirrel4
# Line  80 :
# 	File 1:   - gts=0.7.6=h7c369d9_2
# 	File 2: name: squirrel4
# Line  81 :
# 	File 1:   - harfbuzz=6.0.0=he256f1b_0
# 	File 2: name: squirrel4
# Line  82 :
# 	File 1:   - hdf4=4.2.15=h1b1b6ef_5
# 	File 2: name: squirrel4
# Line  83 :
# 	File 1:   - hdf5=1.12.2=nompi_h57737ce_101
# 	File 2: name: squirrel4
# Line  84 :
# 	File 1:   - holoviews=1.15.4=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  85 :
# 	File 1:   - icu=70.1=h0e60522_0
# 	File 2: name: squirrel4
# Line  86 :
# 	File 1:   - idna=3.4=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  87 :
# 	File 1:   - importlib-metadata=6.0.0=pyha770c72_0
# 	File 2: name: squirrel4
# Line  88 :
# 	File 1:   - importlib-resources=5.12.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  89 :
# 	File 1:   - importlib_metadata=6.0.0=hd8ed1ab_0
# 	File 2: name: squirrel4
# Line  90 :
# 	File 1:   - importlib_resources=5.12.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  91 :
# 	File 1:   - intel-openmp=2023.0.0=h57928b3_25922
# 	File 2: name: squirrel4
# Line  92 :
# 	File 1:   - ipykernel=6.21.2=pyh025b116_0
# 	File 2: name: squirrel4
# Line  93 :
# 	File 1:   - ipython=8.10.0=pyh08f2357_0
# 	File 2: name: squirrel4
# Line  94 :
# 	File 1:   - ipython_genutils=0.2.0=py_1
# 	File 2: name: squirrel4
# Line  95 :
# 	File 1:   - ipywidgets=8.0.4=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  96 :
# 	File 1:   - jedi=0.18.2=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  97 :
# 	File 1:   - jinja2=3.1.2=pyhd8ed1ab_1
# 	File 2: name: squirrel4
# Line  98 :
# 	File 1:   - joblib=1.2.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  99 :
# 	File 1:   - jpeg=9e=hcfcfb64_3
# 	File 2: name: squirrel4
# Line  100 :
# 	File 1:   - jsonschema=4.17.3=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  101 :
# 	File 1:   - jupyter=1.0.0=py39hcbf5309_8
# 	File 2: name: squirrel4
# Line  102 :
# 	File 1:   - jupyter_client=8.0.3=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  103 :
# 	File 1:   - jupyter_console=6.6.1=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  104 :
# 	File 1:   - jupyter_core=5.2.0=py39hcbf5309_0
# 	File 2: name: squirrel4
# Line  105 :
# 	File 1:   - jupyter_events=0.6.3=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  106 :
# 	File 1:   - jupyter_server=2.3.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  107 :
# 	File 1:   - jupyter_server_terminals=0.4.4=pyhd8ed1ab_1
# 	File 2: name: squirrel4
# Line  108 :
# 	File 1:   - jupyterlab_pygments=0.2.2=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  109 :
# 	File 1:   - jupyterlab_widgets=3.0.5=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  110 :
# 	File 1:   - kealib=1.5.0=h61be68b_0
# 	File 2: name: squirrel4
# Line  111 :
# 	File 1:   - kiwisolver=1.4.4=py39h1f6ef14_1
# 	File 2: name: squirrel4
# Line  112 :
# 	File 1:   - krb5=1.20.1=heb0366b_0
# 	File 2: name: squirrel4
# Line  113 :
# 	File 1:   - lcms2=2.14=ha5c8aab_1
# 	File 2: name: squirrel4
# Line  114 :
# 	File 1:   - lerc=4.0.0=h63175ca_0
# 	File 2: name: squirrel4
# Line  115 :
# 	File 1:   - libaec=1.0.6=h63175ca_1
# 	File 2: name: squirrel4
# Line  116 :
# 	File 1:   - libblas=3.9.0=16_win64_mkl
# 	File 2: name: squirrel4
# Line  117 :
# 	File 1:   - libbrotlicommon=1.0.9=hcfcfb64_8
# 	File 2: name: squirrel4
# Line  118 :
# 	File 1:   - libbrotlidec=1.0.9=hcfcfb64_8
# 	File 2: name: squirrel4
# Line  119 :
# 	File 1:   - libbrotlienc=1.0.9=hcfcfb64_8
# 	File 2: name: squirrel4
# Line  120 :
# 	File 1:   - libcblas=3.9.0=16_win64_mkl
# 	File 2: name: squirrel4
# Line  121 :
# 	File 1:   - libclang=15.0.7=default_h77d9078_1
# 	File 2: name: squirrel4
# Line  122 :
# 	File 1:   - libclang13=15.0.7=default_h77d9078_1
# 	File 2: name: squirrel4
# Line  123 :
# 	File 1:   - libcurl=7.88.1=h68f0423_0
# 	File 2: name: squirrel4
# Line  124 :
# 	File 1:   - libdeflate=1.17=hcfcfb64_0
# 	File 2: name: squirrel4
# Line  125 :
# 	File 1:   - libffi=3.4.2=h8ffe710_5
# 	File 2: name: squirrel4
# Line  126 :
# 	File 1:   - libgd=2.3.3=hf5a96e7_4
# 	File 2: name: squirrel4
# Line  127 :
# 	File 1:   - libgdal=3.6.2=h329cd9e_7
# 	File 2: name: squirrel4
# Line  128 :
# 	File 1:   - libglib=2.74.1=he8f3873_1
# 	File 2: name: squirrel4
# Line  129 :
# 	File 1:   - libhwloc=2.8.0=h039e092_1
# 	File 2: name: squirrel4
# Line  130 :
# 	File 1:   - libiconv=1.17=h8ffe710_0
# 	File 2: name: squirrel4
# Line  131 :
# 	File 1:   - libkml=1.3.0=hf2ab4e4_1015
# 	File 2: name: squirrel4
# Line  132 :
# 	File 1:   - liblapack=3.9.0=16_win64_mkl
# 	File 2: name: squirrel4
# Line  133 :
# 	File 1:   - libnetcdf=4.9.1=nompi_hc41bf00_100
# 	File 2: name: squirrel4
# Line  134 :
# 	File 1:   - libogg=1.3.4=h8ffe710_1
# 	File 2: name: squirrel4
# Line  135 :
# 	File 1:   - libpng=1.6.39=h19919ed_0
# 	File 2: name: squirrel4
# Line  136 :
# 	File 1:   - libpq=15.2=ha9684e8_0
# 	File 2: name: squirrel4
# Line  137 :
# 	File 1:   - librttopo=1.1.0=he22b5cd_12
# 	File 2: name: squirrel4
# Line  138 :
# 	File 1:   - libsodium=1.0.18=h8d14728_1
# 	File 2: name: squirrel4
# Line  139 :
# 	File 1:   - libspatialite=5.0.1=hfdcade0_23
# 	File 2: name: squirrel4
# Line  140 :
# 	File 1:   - libsqlite=3.40.0=hcfcfb64_0
# 	File 2: name: squirrel4
# Line  141 :
# 	File 1:   - libssh2=1.10.0=h9a1e1f7_3
# 	File 2: name: squirrel4
# Line  142 :
# 	File 1:   - libtiff=4.5.0=hf8721a0_2
# 	File 2: name: squirrel4
# Line  143 :
# 	File 1:   - libvorbis=1.3.7=h0e60522_0
# 	File 2: name: squirrel4
# Line  144 :
# 	File 1:   - libwebp=1.2.4=hcfcfb64_1
# 	File 2: name: squirrel4
# Line  145 :
# 	File 1:   - libwebp-base=1.2.4=h8ffe710_0
# 	File 2: name: squirrel4
# Line  146 :
# 	File 1:   - libxcb=1.13=hcd874cb_1004
# 	File 2: name: squirrel4
# Line  147 :
# 	File 1:   - libxml2=2.10.3=hc3477c8_0
# 	File 2: name: squirrel4
# Line  148 :
# 	File 1:   - libzip=1.9.2=h519de47_1
# 	File 2: name: squirrel4
# Line  149 :
# 	File 1:   - libzlib=1.2.13=hcfcfb64_4
# 	File 2: name: squirrel4
# Line  150 :
# 	File 1:   - llvmlite=0.39.1=py39hd28a505_1
# 	File 2: name: squirrel4
# Line  151 :
# 	File 1:   - locket=1.0.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  152 :
# 	File 1:   - lz4-c=1.9.4=hcfcfb64_0
# 	File 2: name: squirrel4
# Line  153 :
# 	File 1:   - m2w64-gcc-libgfortran=5.3.0=6
# 	File 2: name: squirrel4
# Line  154 :
# 	File 1:   - m2w64-gcc-libs=5.3.0=7
# 	File 2: name: squirrel4
# Line  155 :
# 	File 1:   - m2w64-gcc-libs-core=5.3.0=7
# 	File 2: name: squirrel4
# Line  156 :
# 	File 1:   - m2w64-gmp=6.1.0=2
# 	File 2: name: squirrel4
# Line  157 :
# 	File 1:   - m2w64-libwinpthread-git=5.0.0.4634.697f757=2
# 	File 2: name: squirrel4
# Line  158 :
# 	File 1:   - mapclassify=2.5.0=pyhd8ed1ab_1
# 	File 2: name: squirrel4
# Line  159 :
# 	File 1:   - markdown=3.4.1=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  160 :
# 	File 1:   - markupsafe=2.1.2=py39ha55989b_0
# 	File 2: name: squirrel4
# Line  161 :
# 	File 1:   - matplotlib=3.7.0=py39hcbf5309_0
# 	File 2: name: squirrel4
# Line  162 :
# 	File 1:   - matplotlib-base=3.7.0=py39haf65ace_0
# 	File 2: name: squirrel4
# Line  163 :
# 	File 1:   - matplotlib-inline=0.1.6=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  164 :
# 	File 1:   - mistune=2.0.5=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  165 :
# 	File 1:   - mkl=2022.1.0=h6a75c08_874
# 	File 2: name: squirrel4
# Line  166 :
# 	File 1:   - msys2-conda-epoch=20160418=1
# 	File 2: name: squirrel4
# Line  167 :
# 	File 1:   - multipledispatch=0.6.0=py_0
# 	File 2: name: squirrel4
# Line  168 :
# 	File 1:   - munkres=1.1.4=pyh9f0ad1d_0
# 	File 2: name: squirrel4
# Line  169 :
# 	File 1:   - nbclassic=0.5.2=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  170 :
# 	File 1:   - nbclient=0.7.2=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  171 :
# 	File 1:   - nbconvert=7.2.9=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  172 :
# 	File 1:   - nbconvert-core=7.2.9=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  173 :
# 	File 1:   - nbconvert-pandoc=7.2.9=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  174 :
# 	File 1:   - nbformat=5.7.3=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  175 :
# 	File 1:   - nest-asyncio=1.5.6=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  176 :
# 	File 1:   - netcdf4=1.6.2=nompi_py39hec31bf5_101
# 	File 2: name: squirrel4
# Line  177 :
# 	File 1:   - networkx=3.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  178 :
# 	File 1:   - notebook=6.5.2=pyha770c72_1
# 	File 2: name: squirrel4
# Line  179 :
# 	File 1:   - notebook-shim=0.2.2=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  180 :
# 	File 1:   - numba=0.56.4=py39h99ae161_0
# 	File 2: name: squirrel4
# Line  181 :
# 	File 1:   - numpy=1.24.2=py39h16ffa76_0
# 	File 2: name: squirrel4
# Line  182 :
# 	File 1:   - openjpeg=2.5.0=ha2aaf27_2
# 	File 2: name: squirrel4
# Line  183 :
# 	File 1:   - openssl=3.0.8=hcfcfb64_0
# 	File 2: name: squirrel4
# Line  184 :
# 	File 1:   - packaging=23.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  185 :
# 	File 1:   - pandas=1.5.3=py39h2ba5b7c_0
# 	File 2: name: squirrel4
# Line  186 :
# 	File 1:   - pandoc=2.19.2=h57928b3_1
# 	File 2: name: squirrel4
# Line  187 :
# 	File 1:   - pandocfilters=1.5.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  188 :
# 	File 1:   - panel=0.14.3=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  189 :
# 	File 1:   - pango=1.50.13=hdffb7b3_0
# 	File 2: name: squirrel4
# Line  190 :
# 	File 1:   - param=1.12.3=pyh1a96a4e_0
# 	File 2: name: squirrel4
# Line  191 :
# 	File 1:   - parso=0.8.3=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  192 :
# 	File 1:   - partd=1.3.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  193 :
# 	File 1:   - pcre2=10.40=h17e33f8_0
# 	File 2: name: squirrel4
# Line  194 :
# 	File 1:   - pickleshare=0.7.5=py_1003
# 	File 2: name: squirrel4
# Line  195 :
# 	File 1:   - pillow=9.4.0=py39hcebd2be_1
# 	File 2: name: squirrel4
# Line  196 :
# 	File 1:   - pip=23.0.1=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  197 :
# 	File 1:   - pixman=0.40.0=h8ffe710_0
# 	File 2: name: squirrel4
# Line  198 :
# 	File 1:   - pkgutil-resolve-name=1.3.10=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  199 :
# 	File 1:   - platformdirs=3.0.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  200 :
# 	File 1:   - ply=3.11=py_1
# 	File 2: name: squirrel4
# Line  201 :
# 	File 1:   - pooch=1.6.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  202 :
# 	File 1:   - poppler=23.01.0=h183ae7b_0
# 	File 2: name: squirrel4
# Line  203 :
# 	File 1:   - poppler-data=0.4.12=hd8ed1ab_0
# 	File 2: name: squirrel4
# Line  204 :
# 	File 1:   - postgresql=15.2=hd87cd2b_0
# 	File 2: name: squirrel4
# Line  205 :
# 	File 1:   - proj=9.1.1=heca977f_2
# 	File 2: name: squirrel4
# Line  206 :
# 	File 1:   - prometheus_client=0.16.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  207 :
# 	File 1:   - prompt-toolkit=3.0.36=pyha770c72_0
# 	File 2: name: squirrel4
# Line  208 :
# 	File 1:   - psutil=5.9.4=py39ha55989b_0
# 	File 2: name: squirrel4
# Line  209 :
# 	File 1:   - pthread-stubs=0.4=hcd874cb_1001
# 	File 2: name: squirrel4
# Line  210 :
# 	File 1:   - pthreads-win32=2.9.1=hfa6e2cd_3
# 	File 2: name: squirrel4
# Line  211 :
# 	File 1:   - pure_eval=0.2.2=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  212 :
# 	File 1:   - pycparser=2.21=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  213 :
# 	File 1:   - pyct=0.4.6=py_0
# 	File 2: name: squirrel4
# Line  214 :
# 	File 1:   - pyct-core=0.4.6=py_0
# 	File 2: name: squirrel4
# Line  215 :
# 	File 1:   - pygeos=0.14=py39h7c5f289_0
# 	File 2: name: squirrel4
# Line  216 :
# 	File 1:   - pygments=2.14.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  217 :
# 	File 1:   - pyogrio=0.5.1=py39h72cb054_0
# 	File 2: name: squirrel4
# Line  218 :
# 	File 1:   - pyopenssl=23.0.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  219 :
# 	File 1:   - pyparsing=3.0.9=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  220 :
# 	File 1:   - pyproj=3.4.1=py39hc799f2e_1
# 	File 2: name: squirrel4
# Line  221 :
# 	File 1:   - pyqt=5.15.7=py39hb77abff_3
# 	File 2: name: squirrel4
# Line  222 :
# 	File 1:   - pyqt5-sip=12.11.0=py39h99910a6_3
# 	File 2: name: squirrel4
# Line  223 :
# 	File 1:   - pyrsistent=0.19.3=py39ha55989b_0
# 	File 2: name: squirrel4
# Line  224 :
# 	File 1:   - pyshp=2.3.1=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  225 :
# 	File 1:   - pysocks=1.7.1=pyh0701188_6
# 	File 2: name: squirrel4
# Line  226 :
# 	File 1:   - python=3.9.16=h4de0772_0_cpython
# 	File 2: name: squirrel4
# Line  227 :
# 	File 1:   - python-dateutil=2.8.2=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  228 :
# 	File 1:   - python-fastjsonschema=2.16.2=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  229 :
# 	File 1:   - python-json-logger=2.0.6=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  230 :
# 	File 1:   - python_abi=3.9=3_cp39
# 	File 2: name: squirrel4
# Line  231 :
# 	File 1:   - pytz=2022.7.1=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  232 :
# 	File 1:   - pyviz_comms=2.2.1=pyhd8ed1ab_1
# 	File 2: name: squirrel4
# Line  233 :
# 	File 1:   - pywin32=304=py39h99910a6_2
# 	File 2: name: squirrel4
# Line  234 :
# 	File 1:   - pywinpty=2.0.10=py39h99910a6_0
# 	File 2: name: squirrel4
# Line  235 :
# 	File 1:   - pyyaml=6.0=py39ha55989b_5
# 	File 2: name: squirrel4
# Line  236 :
# 	File 1:   - pyzmq=25.0.0=py39hea35a22_0
# 	File 2: name: squirrel4
# Line  237 :
# 	File 1:   - qt-main=5.15.8=h720456b_6
# 	File 2: name: squirrel4
# Line  238 :
# 	File 1:   - qtconsole=5.4.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  239 :
# 	File 1:   - qtconsole-base=5.4.0=pyha770c72_0
# 	File 2: name: squirrel4
# Line  240 :
# 	File 1:   - qtpy=2.3.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  241 :
# 	File 1:   - requests=2.28.2=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  242 :
# 	File 1:   - rfc3339-validator=0.1.4=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  243 :
# 	File 1:   - rfc3986-validator=0.1.1=pyh9f0ad1d_0
# 	File 2: name: squirrel4
# Line  244 :
# 	File 1:   - scikit-learn=1.2.1=py39h6fe01c0_0
# 	File 2: name: squirrel4
# Line  245 :
# 	File 1:   - scipy=1.10.0=py39hfbf2dce_2
# 	File 2: name: squirrel4
# Line  246 :
# 	File 1:   - send2trash=1.8.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  247 :
# 	File 1:   - setuptools=67.3.2=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  248 :
# 	File 1:   - shapely=2.0.1=py39h7c5f289_0
# 	File 2: name: squirrel4
# Line  249 :
# 	File 1:   - sip=6.7.7=py39h99910a6_0
# 	File 2: name: squirrel4
# Line  250 :
# 	File 1:   - six=1.16.0=pyh6c4a22f_0
# 	File 2: name: squirrel4
# Line  251 :
# 	File 1:   - snappy=1.1.9=hfb803bf_2
# 	File 2: name: squirrel4
# Line  252 :
# 	File 1:   - sniffio=1.3.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  253 :
# 	File 1:   - soupsieve=2.3.2.post1=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  254 :
# 	File 1:   - sqlite=3.40.0=hcfcfb64_0
# 	File 2: name: squirrel4
# Line  255 :
# 	File 1:   - stack_data=0.6.2=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  256 :
# 	File 1:   - tbb=2021.7.0=h91493d7_1
# 	File 2: name: squirrel4
# Line  257 :
# 	File 1:   - terminado=0.15.0=py39hcbf5309_0
# 	File 2: name: squirrel4
# Line  258 :
# 	File 1:   - threadpoolctl=3.1.0=pyh8a188c0_0
# 	File 2: name: squirrel4
# Line  259 :
# 	File 1:   - tiledb=2.13.2=h3132609_0
# 	File 2: name: squirrel4
# Line  260 :
# 	File 1:   - tinycss2=1.2.1=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  261 :
# 	File 1:   - tk=8.6.12=h8ffe710_0
# 	File 2: name: squirrel4
# Line  262 :
# 	File 1:   - toml=0.10.2=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  263 :
# 	File 1:   - toolz=0.12.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  264 :
# 	File 1:   - tornado=6.2=py39ha55989b_1
# 	File 2: name: squirrel4
# Line  265 :
# 	File 1:   - tqdm=4.64.1=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  266 :
# 	File 1:   - traitlets=5.9.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  267 :
# 	File 1:   - typing-extensions=4.4.0=hd8ed1ab_0
# 	File 2: name: squirrel4
# Line  268 :
# 	File 1:   - typing_extensions=4.4.0=pyha770c72_0
# 	File 2: name: squirrel4
# Line  269 :
# 	File 1:   - tzdata=2022g=h191b570_0
# 	File 2: name: squirrel4
# Line  270 :
# 	File 1:   - ucrt=10.0.22621.0=h57928b3_0
# 	File 2: name: squirrel4
# Line  271 :
# 	File 1:   - unicodedata2=15.0.0=py39ha55989b_0
# 	File 2: name: squirrel4
# Line  272 :
# 	File 1:   - urllib3=1.26.14=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  273 :
# 	File 1:   - vc=14.3=hb6edc58_10
# 	File 2: name: squirrel4
# Line  274 :
# 	File 1:   - vs2015_runtime=14.34.31931=h4c5c07a_10
# 	File 2: name: squirrel4
# Line  275 :
# 	File 1:   - wcwidth=0.2.6=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  276 :
# 	File 1:   - webencodings=0.5.1=py_1
# 	File 2: name: squirrel4
# Line  277 :
# 	File 1:   - websocket-client=1.5.1=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  278 :
# 	File 1:   - wheel=0.38.4=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  279 :
# 	File 1:   - widgetsnbextension=4.0.5=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  280 :
# 	File 1:   - win_inet_pton=1.1.0=pyhd8ed1ab_6
# 	File 2: name: squirrel4
# Line  281 :
# 	File 1:   - winpty=0.4.3=4
# 	File 2: name: squirrel4
# Line  282 :
# 	File 1:   - xarray=2023.2.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  283 :
# 	File 1:   - xerces-c=3.2.4=h63175ca_1
# 	File 2: name: squirrel4
# Line  284 :
# 	File 1:   - xorg-kbproto=1.0.7=hcd874cb_1002
# 	File 2: name: squirrel4
# Line  285 :
# 	File 1:   - xorg-libice=1.0.10=hcd874cb_0
# 	File 2: name: squirrel4
# Line  286 :
# 	File 1:   - xorg-libsm=1.2.3=hcd874cb_1000
# 	File 2: name: squirrel4
# Line  287 :
# 	File 1:   - xorg-libx11=1.7.2=hcd874cb_0
# 	File 2: name: squirrel4
# Line  288 :
# 	File 1:   - xorg-libxau=1.0.9=hcd874cb_0
# 	File 2: name: squirrel4
# Line  289 :
# 	File 1:   - xorg-libxdmcp=1.1.3=hcd874cb_0
# 	File 2: name: squirrel4
# Line  290 :
# 	File 1:   - xorg-libxext=1.3.4=hcd874cb_1
# 	File 2: name: squirrel4
# Line  291 :
# 	File 1:   - xorg-libxpm=3.5.13=hcd874cb_0
# 	File 2: name: squirrel4
# Line  292 :
# 	File 1:   - xorg-libxt=1.2.1=hcd874cb_2
# 	File 2: name: squirrel4
# Line  293 :
# 	File 1:   - xorg-xextproto=7.3.0=hcd874cb_1002
# 	File 2: name: squirrel4
# Line  294 :
# 	File 1:   - xorg-xproto=7.0.31=hcd874cb_1007
# 	File 2: name: squirrel4
# Line  295 :
# 	File 1:   - xz=5.2.6=h8d14728_0
# 	File 2: name: squirrel4
# Line  296 :
# 	File 1:   - yaml=0.2.5=h8ffe710_2
# 	File 2: name: squirrel4
# Line  297 :
# 	File 1:   - zeromq=4.3.4=h0e60522_1
# 	File 2: name: squirrel4
# Line  298 :
# 	File 1:   - zipp=3.14.0=pyhd8ed1ab_0
# 	File 2: name: squirrel4
# Line  299 :
# 	File 1:   - zlib=1.2.13=hcfcfb64_4
# 	File 2: name: squirrel4
# Line  300 :
# 	File 1:   - zstd=1.5.2=h12be248_6
# 	File 2: name: squirrel4
# Line  301 :
# 	File 1: prefix: C:\Users\Admin\miniconda3\envs\squirrel
# 	File 2: name: squirrel4

# %%
file1 = open("emails_A.txt",'r')
file2 = open("emails_B.txt",'r')

file1_lines = file1.readlines()
file2_lines = file2.readlines()

for i in range(len(file1_lines)):
    if file1_lines[i] != file2_lines[i]:
        print("Line " + str(i+1) + " doesn't match.")
        print("------------------------")
        print("File1: " + file1_lines[i])
        print("File2: " + file2_lines[i])

file1.close()
file2.close()
